# %% [markdown]
# **PROJECT - EXPLORATORY DATA ANALYSIS (EDA)**

# %% [markdown]
# **COMMUNITY HEALTH EVALUATION**

# %% [markdown]
# **Numpy**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import numpy as np
import pandas as pd

data = pd.read_csv('/content/community_health_evaluation_dataset.csv')
data.head()
# Out:
#    Participant ID  Age Gender  SES  Service Type Visit Frequency  \
# 0               1   56      F    4         Rehab          Weekly
# 1               2   69      M    1    Preventive          Yearly
# 2               3   46      M    4         Rehab          Yearly
# 3               4   32      F    1  Consultation          Weekly
# 4               5   60      M    3    Preventive          Weekly
#
#    Step Frequency (steps/min)  Stride Length (m)  Joint Angle (°)  \
# 0                          85               0.54            17.99
# 1                          80               0.70            13.05
# 2                          81               0.57            29.85
# 3                          66               0.78            28.54
# 4                          73               0.84            20.80
#
#   EMG Activity  Patient Satisfaction (1-10)  Quality of Life Score
# 0          Low                            1                     57
# ...

# %%
# Convert columns to numpy arrays

array = data.to_numpy()
print(array)
# Out:
# [[1 56 'F' ... 'Low' 1 57]
#  [2 69 'M' ... 'Moderate' 8 94]
#  [3 46 'M' ... 'Moderate' 4 66]
#  ...
#  [345 34 'F' ... 'Low' 7 60]
#  [346 50 'M' ... 'Moderate' 3 57]
#  [347 65 'F' ... 'Low' 9 82]]

# %%
Age = data['Age'].to_numpy()
gender = data['Gender'].to_numpy()
Emg_Activity = data['EMG Activity'].to_numpy()
ses = data['SES'].to_numpy()

print(Age)
print(gender)
print(Emg_Activity)
print(ses)
# Out:
# [56 69 46 32 60 25 38 56 36 40 28 28 41 53 57 41 20 39 19 41 61 47 55 19
#  38 50 29 39 61 42 66 44 59 45 33 32 64 68 61 69 20 54 68 24 38 26 56 35
#  21 42 31 67 26 43 19 37 45 64 24 61 25 64 52 31 34 53 67 57 21 19 23 59
#  21 46 35 43 61 51 27 53 31 48 65 32 25 31 40 57 38 33 62 35 64 41 43 42
#  62 58 46 32 62 18 42 24 26 41 18 61 25 41 28 68 34 25 52 52 50 22 59 56
#  58 45 24 26 25 29 51 50 65 40 41 54 52 61 57 39 44 52 18 52 54 64 31 20
#  18 22 43 31 56 44 26 32 32 43 59 30 68 49 56 66 69 49 21 47 54 40 56 62
#  32 60 46 53 30 49 24 68 39 45 19 59 62 23 45 45 61 61 37 47 28 45 42 56
#  50 18 44 69 30 58 20 56 23 25 44 26 54 50 68 59 61 41 32 49 49 41 58 69
#  66 66 69 29 56 19 20 66 54 66 34 66 19 19 45 40 54 49 50 18 36 19 61 43
#  49 23 49 21 28 34 55 41 22 69 51 23 39 28 65 33 50 26 23 33 46 20 37 53
#  36 43 20 36 37 49 24 69 58 50 57 56 35 57 18 28 45 42 67 40 48 47 59 52
#  24 33 43 65 69 66 19 18 65 29 22 54 49 26 58 52 36 65 33 20 37 41 50 41
# ...

# %%
import numpy as np

mean_Age = np.mean(Age)
mean_ses = np.mean(ses)

print(mean_Age)
print(mean_ses)
# Out:
# 43.37463976945245
# 2.357348703170029

# %%
print(min(Age))
print(max(Age))
# Out:
# 18
# 69

# %%
print(Age.shape)
# Out:
# (347,)

# %%
print(Age.ndim)
# Out:
# 1

# %%
print(Age.dtype)
# Out:
# int64

# %%
print(mean_ses)

print(np.median(ses))
# Out:
# 2.357348703170029
# 2.0

# %%
print(max(ses))
print(min(ses))
# Out:
# 4
# 1

# %% [markdown]
# **Pandas**

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/community_health_evaluation_dataset.csv')
df.head()
# Out:
#    Participant ID  Age Gender  SES  Service Type Visit Frequency  \
# 0               1   56      F    4         Rehab          Weekly
# 1               2   69      M    1    Preventive          Yearly
# 2               3   46      M    4         Rehab          Yearly
# 3               4   32      F    1  Consultation          Weekly
# 4               5   60      M    3    Preventive          Weekly
#
#    Step Frequency (steps/min)  Stride Length (m)  Joint Angle (°)  \
# 0                          85               0.54            17.99
# 1                          80               0.70            13.05
# 2                          81               0.57            29.85
# 3                          66               0.78            28.54
# 4                          73               0.84            20.80
#
#   EMG Activity  Patient Satisfaction (1-10)  Quality of Life Score
# 0          Low                            1                     57
# ...

# %%
df.tail()
# Out:
#      Participant ID  Age Gender  SES Service Type Visit Frequency  \
# 342             343   24      M    3   Preventive          Yearly
# 343             344   20      F    3        Rehab         Monthly
# 344             345   34      F    3   Preventive          Yearly
# 345             346   50      M    3   Preventive          Weekly
# 346             347   65      F    2        Rehab          Yearly
#
#      Step Frequency (steps/min)  Stride Length (m)  Joint Angle (°)  \
# 342                          92               0.67            27.45
# 343                          72               0.83            26.84
# 344                          89               0.90            13.72
# 345                          92               0.96            26.05
# 346                          72               0.62            19.16
#
#     EMG Activity  Patient Satisfaction (1-10)  Quality of Life Score
# 342          Low                            3                     58
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 347 entries, 0 to 346
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Participant ID               347 non-null    int64
#  1   Age                          347 non-null    int64
#  2   Gender                       347 non-null    object
#  3   SES                          347 non-null    int64
#  4   Service Type                 347 non-null    object
#  5   Visit Frequency              347 non-null    object
#  6   Step Frequency (steps/min)   347 non-null    int64
#  7   Stride Length (m)            347 non-null    float64
#  8   Joint Angle (°)              347 non-null    float64
#  9   EMG Activity                 347 non-null    object
#  10  Patient Satisfaction (1-10)  347 non-null    int64
#  11  Quality of Life Score        347 non-null    int64
# dtypes: float64(2), int64(6), object(4)
# memory usage: 32.7+ KB

# %%
df.describe()
# Out:
#        Participant ID         Age         SES  Step Frequency (steps/min)  \
# count      347.000000  347.000000  347.000000                  347.000000
# mean       174.000000   43.374640    2.357349                   80.123919
# std        100.314505   15.177304    1.129848                   11.257582
# min          1.000000   18.000000    1.000000                   60.000000
# 25%         87.500000   31.000000    1.000000                   71.000000
# 50%        174.000000   43.000000    2.000000                   81.000000
# 75%        260.500000   56.000000    3.000000                   90.000000
# max        347.000000   69.000000    4.000000                   99.000000
#
#        Stride Length (m)  Joint Angle (°)  Patient Satisfaction (1-10)  \
# count         347.000000       347.000000                   347.000000
# mean            0.751499        20.057378                     5.213256
# std             0.143221         5.807653                     2.833643
# ...

# %%
# Check for missing values

print(df.isnull().sum())
# Out:
# Participant ID                 0
# Age                            0
# Gender                         0
# SES                            0
# Service Type                   0
# Visit Frequency                0
# Step Frequency (steps/min)     0
# Stride Length (m)              0
# Joint Angle (°)                0
# EMG Activity                   0
# Patient Satisfaction (1-10)    0
# Quality of Life Score          0
# dtype: int64

# %%
# Filter rows with specific condition

#filtered_df = df[df['Patient Satisfaction (1-10)'] < 5]
#print(filtered_df)
# Out:
#      Participant ID  Age Gender  SES  Service Type Visit Frequency  \
# 0                 1   56      F    4         Rehab          Weekly
# 2                 3   46      M    4         Rehab          Yearly
# 5                 6   25      F    1  Consultation          Yearly
# 8                 9   36      F    3         Rehab          Yearly
# 9                10   40      F    1         Rehab         Monthly
# ..              ...  ...    ...  ...           ...             ...
# 339             340   65      F    2    Preventive          Weekly
# 341             342   25      M    2  Consultation         Monthly
# 342             343   24      M    3    Preventive          Yearly
# 343             344   20      F    3         Rehab         Monthly
# 345             346   50      M    3    Preventive          Weekly
#
#      Step Frequency (steps/min)  Stride Length (m)  Joint Angle (°)  \
# 0                            85               0.54            17.99
# ...

# %%
# Find unique values in each colud

unique_values = df.nunique()
print(unique_values)
# Out:
# Participant ID                 347
# Age                             52
# Gender                           2
# SES                              4
# Service Type                     3
# Visit Frequency                  3
# Step Frequency (steps/min)      40
# Stride Length (m)               51
# Joint Angle (°)                316
# EMG Activity                     3
# Patient Satisfaction (1-10)     10
# Quality of Life Score           50
# dtype: int64

# %% [markdown]
# **Matplotlib**

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('/content/community_health_evaluation_dataset.csv')
df.head()
# Out:
#    Participant ID  Age Gender  SES  Service Type Visit Frequency  \
# 0               1   56      F    4         Rehab          Weekly
# 1               2   69      M    1    Preventive          Yearly
# 2               3   46      M    4         Rehab          Yearly
# 3               4   32      F    1  Consultation          Weekly
# 4               5   60      M    3    Preventive          Weekly
#
#    Step Frequency (steps/min)  Stride Length (m)  Joint Angle (°)  \
# 0                          85               0.54            17.99
# 1                          80               0.70            13.05
# 2                          81               0.57            29.85
# 3                          66               0.78            28.54
# 4                          73               0.84            20.80
#
#   EMG Activity  Patient Satisfaction (1-10)  Quality of Life Score
# 0          Low                            1                     57
# ...

# %%
# Histogram of Age

plt.hist(Age,bins=5,rwidth=0.5,color=['k'])

plt.xlabel('Age')
plt.ylabel('Quality of Life Score')
plt.title('Quality of Life Score')
plt.show()

# %% [markdown]
# 1 - Inthe Age of 30-35 Quality of Life Score is Low
#
# 2 - Quality of Life Score is High in the Age inbetween 50-55
#
# 3 - Avarege Quality of Life Score is inbetween 40-45
#
# * Age is not depend the Quality of life

# %% [markdown]
# **Age distribution**  A histogram showing the distribution of age

# %%
# Bar chart of Gender

gender_counts = df['Gender'].value_counts(10)
plt.bar(gender_counts.index, gender_counts.values)
plt.xlabel('Gender')
plt.ylabel('Patient Satisfaction (1-10)')
plt.title('Gender Distribution')
plt.show()

# %% [markdown]
# * Patient satisfaction is High in Females

# %%
#scatter plot

plt.scatter(df['Age'], df['Quality of Life Score'])
plt.xlabel('Age')
plt.ylabel('Quality of Life Score')
plt.title(' Quality of Life Score by Age')
plt.show()

# %% [markdown]
# THe quality of life score is does not effect by the age

# %%
#box plot
sns.boxplot(x = "Gender", y = "Quality of Life Score", data = df)
plt.title("Quality of Life Score by Gender")
plt.show()

# %% [markdown]
# In this plot we can see that gender is not an important parameter in Quality of life.
#
# There are no outliners in any of the groups

# %%
#pie chart

Visit_Frequency =df['Visit Frequency'].value_counts()
Quality_of_Life_Score = df['Quality of Life Score'].value_counts()
plt.pie(Visit_Frequency, labels=Visit_Frequency.index,startangle=90,shadow='True',explode=(1,0,1),autopct='%1.3f%%')
plt.title('Visit Frequency')
plt.show()

# %% [markdown]
# ** visit Frequency **
#
# * yearly  - 33.429%
#
# * monthly - 31.988%
#
# * weekly  - 34.582%

# %% [markdown]
# **Seaborn**

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('/content/community_health_evaluation_dataset.csv')
df.head()
# Out:
#    Participant ID  Age Gender  SES  Service Type Visit Frequency  \
# 0               1   56      F    4         Rehab          Weekly
# 1               2   69      M    1    Preventive          Yearly
# 2               3   46      M    4         Rehab          Yearly
# 3               4   32      F    1  Consultation          Weekly
# 4               5   60      M    3    Preventive          Weekly
#
#    Step Frequency (steps/min)  Stride Length (m)  Joint Angle (°)  \
# 0                          85               0.54            17.99
# 1                          80               0.70            13.05
# 2                          81               0.57            29.85
# 3                          66               0.78            28.54
# 4                          73               0.84            20.80
#
#   EMG Activity  Patient Satisfaction (1-10)  Quality of Life Score
# 0          Low                            1                     57
# ...

# %%
# Histogram of Age

sns.histplot(data['Age'], bins=30, kde=True)
plt.xlabel('Age')
plt.ylabel('Step Frequency (steps/min)')
plt.title('Age Distribution')
plt.show()

# %% [markdown]
# * step frequency different in diffrent ages
#
# * high in Age of 48-50
#
# * Low in Age of 63-65

# %%
#scatter plot

sns.scatterplot(x='Age', y='Quality of Life Score',hue='Gender', data=df)
plt.xlabel('Age')
plt.ylabel('Quality of Life Score')
plt.title('Quality of Life Score by Age')
plt.show()

# %% [markdown]
# The quality of life does not depents Age

# %%
#box plot

sns.boxplot(x='SES', y='Quality of Life Score',hue='Gender',data=df)
plt.title('Quality of Life Score by SES')
plt.show()

# %% [markdown]
# ses does not depent quality of life in males and females

# %%
# Violin plot of SES by Gender

sns.violinplot(x='Gender', y='SES', data=data)
plt.title('SES by Gender')
plt.show()

# %% [markdown]
# A violin plot showing SES distribution by gender

# %%
numeric_df = df.select_dtypes(include=[np.number])
plt.figure(figsize=(10, 8))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# **Conclution**
#
# * Age does not depent Quality of life
#
# * The high SES value does not indicate high quality of life
#
# * There is no diffrents in life quality between males and females
